# %% [markdown]
# # Former i Glowscript
#
# Pythons Glowscript modul er lavet til 3D simulering. Det er relativt let at sætte forskellige former ind.
#
# Nedenunder er vist forskellige former via en embedded Trinket.

# %%
from IPython.display import IFrame

# Viser Trinket-simuleringen direkte i din Notebook
IFrame(src=' https://glowscript.org/#/user/mps/folder/MyPrograms/program/jordensattelites', width='100%', height='400')
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src=" https://glowscript.org/#/user/mps/folder/MyPrograms/program/jordensattelites"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Øvelser og Eksperimenter
#
# * Man kan fjerne linjer med `#` – det hedder at **udkommentere**.
#
# Som I kan se, bliver positionen defineret ved en vektor. For at få styr på akserne, så prøv at udkommentere de andre figurer.
#
# **Prøv følgende:**
# 1. Dan 3 vektorer i tre linjer:
#    * `arrow(axis=vec(1,0,0))`
#    * `arrow(axis=vec(0,1,0), color=color.red)`
#    * `arrow(axis=vec(0,0,1), color=color.blue)`
# 2. Vektoren er defineret som `vec(x,y,z)`. Hvordan er orienteringen i programmet?
#
# I kan finde flere figurer her: [Glowscript Primitives](http://www.glowscript.org/docs/VPythonDocs/primitives.html)
